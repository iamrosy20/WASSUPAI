# %% [markdown]
# # **영화 추천 시스템**
# MovieLens 데이터로 사용자의 영화 평점 패턴 학습
#
# → 비어 있는 평점 예측 (사용자가 아직 보지 않은 영화에 대해 어떻게 평가할지 예측)

# %%
import pandas as pd
import tensorflow.keras.backend as K
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ### **1. Load dataset**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load dataset
ratings = pd.read_csv('/content/drive/MyDrive/Samples/ratings.csv')
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100836 non-null  int64
#  1   movieId    100836 non-null  int64
#  2   rating     100836 non-null  float64
#  3   timestamp  100836 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %%
display(ratings.head())
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %% [markdown]
# ### **2. Data Preprocessing**

# %%
# Select some columns
ratings = ratings[['userId', 'movieId', 'rating']]

# %%
# Create rating matrix
ratings_matrix = ratings.pivot(index='userId', columns='movieId', values='rating')
print(ratings_matrix.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 610 entries, 1 to 610
# Columns: 9724 entries, 1 to 193609
# dtypes: float64(9724)
# memory usage: 45.3 MB
# None

# %%
display(ratings_matrix.head())
# Out:
# movieId  1       2       3       4       5       6       7       8       \
# userId
# 1           4.0     NaN     4.0     NaN     NaN     4.0     NaN     NaN
# 2           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5           4.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# movieId  9       10      ...  193565  193567  193571  193573  193579  193581  \
# userId                   ...
# 1           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 5           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
#
# movieId  193583  193585  193587  193609
# userId
# 1           NaN     NaN     NaN     NaN
# 2           NaN     NaN     NaN     NaN
# 3           NaN     NaN     NaN     NaN
# 4           NaN     NaN     NaN     NaN
# 5           NaN     NaN     NaN     NaN
#
# [5 rows x 9724 columns]

# %%
# Fill review value of unseen movie as 0
ratings_matrix.fillna(0, inplace=True)

# %%
# Normalize review value
ratings_matrix = ratings_matrix.values / 5.0

# %% [markdown]
# ### **3. Modeling**

# %%
# Split the dataset
x_train, x_val = train_test_split(ratings_matrix, test_size=0.2, random_state=42)

# %%
# Build autoencoder model
input_layer = Input(shape=(ratings_matrix.shape[1],))                            # input layer
encoded = Dense(9724, activation='relu')(input_layer)
encoded = Dense(1024, activation='relu')(encoded)
encoded = Dense(512, activation='relu')(encoded)                            # encoder (dimension reduction)
encoded = Dense(256, activation='relu')(encoded)
encoded = Dense(128, activation='relu')(encoded)
encoded = Dense(64, activation='relu')(encoded)
decoded = Dense(128, activation='relu')(encoded)                                # decoder (dimension expansion)
decoded = Dense(256, activation='relu')(decoded)
decoded = Dense(512, activation='relu')(decoded)
decoded = Dense(1024, activation='relu')(decoded)
decoded = Dense(9724, activation='relu')(decoded)
output_layer = Dense(ratings_matrix.shape[1], activation='sigmoid')(decoded)    # output layer
autoencoder = Model(input_layer, output_layer)
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 9724)]            0
#
#  dense (Dense)               (None, 9724)              94565900
#
#  dense_1 (Dense)             (None, 1024)              9958400
#
#  dense_2 (Dense)             (None, 512)               524800
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dense_5 (Dense)             (None, 64)                8256
#
#  dense_6 (Dense)             (None, 128)               8320
#
#  dense_7 (Dense)             (None, 256)               33024
#
#  dense_8 (Dense)             (None, 512)               131584
#
#  dense_9 (Dense)             (None, 1024)              525312
#
#  dense_10 (Dense)            (None, 9724)              9967100
#
#  dense_11 (Dense)            (None, 9724)              94565900
#
# =================================================================
# Total params: 210452820 (802.81 MB)
# Trainable params: 210452820 (802.81 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Define a loss function that calculates loss by only using real rating value
def masked_mse(y_true, y_pred):                         # masking technique
    mask = K.cast(K.not_equal(y_true, 0), K.floatx())   # if real rating value then 1, else fake rating value then 0
    error = K.square((y_true - y_pred) * mask)          # loss of fake rating value becomes 0 (only taking loss of real rating value)
    return K.sum(error) / K.sum(mask)                   # calculate MSE

# %%
# Compile
autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss=masked_mse)

# %%
# Fit the model
autoencoder.fit(x_train, x_train, epochs=50, batch_size=256, validation_data=(x_val, x_val))
# Out:
# Epoch 1/50
# 2/2 [==============================] - 27s 11s/step - loss: 0.0863 - val_loss: 0.0754
# Epoch 2/50
# 2/2 [==============================] - 23s 15s/step - loss: 0.0797 - val_loss: 0.0574
# Epoch 3/50
# 2/2 [==============================] - 24s 11s/step - loss: 0.0541 - val_loss: 0.0444
# Epoch 4/50
# 2/2 [==============================] - 22s 11s/step - loss: 0.0457 - val_loss: 0.0433
# Epoch 5/50
# 2/2 [==============================] - 22s 11s/step - loss: 0.0382 - val_loss: 0.0349
# Epoch 6/50
# 2/2 [==============================] - 21s 11s/step - loss: 0.0347 - val_loss: 0.0357
# Epoch 7/50
# 2/2 [==============================] - 23s 12s/step - loss: 0.0311 - val_loss: 0.0350
# Epoch 8/50
# 2/2 [==============================] - 21s 12s/step - loss: 0.0306 - val_loss: 0.0346
# Epoch 9/50
# 2/2 [==============================] - 24s 13s/step - loss: 0.0295 - val_loss: 0.0338
# Epoch 10/50
# 2/2 [==============================] - 21s 11s/step - loss: 0.0287 - val_loss: 0.0334
# Epoch 11/50
# 2/2 [==============================] - 22s 11s/step - loss: 0.0283 - val_loss: 0.0336
# Epoch 12/50
# 2/2 [==============================] - 21s 11s/step - loss: 0.0278 - val_loss: 0.0344
# Epoch 13/50
# 2/2 [==============================] - 22s 11s/step - loss: 0.0281 - val_loss: 0.0339
# Epoch 14/50
# 2/2 [==============================] - 20s 11s/step - loss: 0.0275 - val_loss: 0.0341
# Epoch 15/50
# 2/2 [==============================] - 21s 11s/step - loss: 0.0270 - val_loss: 0.0335
# Epoch 16/50
# 2/2 [==============================] - 21s 11s/step - loss: 0.0272 - val_loss: 0.0342
# Epoch 17/50
# 2/2 [==============================] - 21s 10s/step - loss: 0.0271 - val_loss: 0.0341
# Epoch 18/50
# 2/2 [==============================] - 23s 11s/step - loss: 0.0271 - val_loss: 0.0342
# Epoch 19/50
# 2/2 [==============================] - 21s 10s/step - loss: 0.0267 - val_loss: 0.0343
# Epoch 20/50
# 2/2 [==============================] - 21s 11s/step - loss: 0.0268 - val_loss: 0.0339
# Epoch 21/50
# 2/2 [==============================] - 21s 10s/step - loss: 0.0268 - val_loss: 0.0345
# Epoch 22/50
# 2/2 [==============================] - 22s 11s/step - loss: 0.0266 - val_loss: 0.0342
# Epoch 23/50
# 2/2 [==============================] - 21s 10s/step - loss: 0.0266 - val_loss: 0.0346
# Epoch 24/50
# 2/2 [==============================] - 23s 11s/step - loss: 0.0268 - val_loss: 0.0343
# Epoch 25/50
# 2/2 [==============================] - 21s 10s/step - loss: 0.0264 - val_loss: 0.0347
# Epoch 26/50
# 2/2 [==============================] - 22s 11s/step - loss: 0.0268 - val_loss: 0.0345
# Epoch 27/50
# 2/2 [==============================] - 23s 10s/step - loss: 0.0264 - val_loss: 0.0347
# Epoch 28/50
# 2/2 [==============================] - 22s 12s/step - loss: 0.0263 - val_loss: 0.0346
# Epoch 29/50
# 2/2 [==============================] - 21s 11s/step - loss: 0.0264 - val_loss: 0.0347
# Epoch 30/50
# 2/2 [==============================] - 34s 23s/step - loss: 0.0264 - val_loss: 0.0347
# Epoch 31/50
# 2/2 [==============================] - 22s 11s/step - loss: 0.0263 - val_loss: 0.0348
# Epoch 32/50
# 2/2 [==============================] - 22s 11s/step - loss: 0.0262 - val_loss: 0.0348
# Epoch 33/50
# 2/2 [==============================] - 21s 11s/step - loss: 0.0261 - val_loss: 0.0348
# Epoch 34/50
# 2/2 [==============================] - 22s 11s/step - loss: 0.0261 - val_loss: 0.0347
# Epoch 35/50
# 2/2 [==============================] - 22s 12s/step - loss: 0.0260 - val_loss: 0.0349
# Epoch 36/50
# 2/2 [==============================] - 22s 11s/step - loss: 0.0259 - val_loss: 0.0347
# Epoch 37/50
# 2/2 [==============================] - 21s 11s/step - loss: 0.0258 - val_loss: 0.0350
# Epoch 38/50
# 2/2 [==============================] - 22s 11s/step - loss: 0.0256 - val_loss: 0.0346
# Epoch 39/50
# 2/2 [==============================] - 21s 11s/step - loss: 0.0255 - val_loss: 0.0351
# Epoch 40/50
# 2/2 [==============================] - 23s 12s/step - loss: 0.0253 - val_loss: 0.0350
# Epoch 41/50
# 2/2 [==============================] - 21s 10s/step - loss: 0.0251 - val_loss: 0.0350
# Epoch 42/50
# 2/2 [==============================] - 22s 11s/step - loss: 0.0248 - val_loss: 0.0356
# Epoch 43/50
# 2/2 [==============================] - 21s 10s/step - loss: 0.0245 - val_loss: 0.0345
# Epoch 44/50
# 2/2 [==============================] - 23s 11s/step - loss: 0.0244 - val_loss: 0.0372
# Epoch 45/50
# 2/2 [==============================] - 22s 11s/step - loss: 0.0248 - val_loss: 0.0346
# Epoch 46/50
# 2/2 [==============================] - 21s 11s/step - loss: 0.0246 - val_loss: 0.0369
# Epoch 47/50
# 2/2 [==============================] - 22s 11s/step - loss: 0.0245 - val_loss: 0.0352
# Epoch 48/50
# 2/2 [==============================] - 21s 11s/step - loss: 0.0238 - val_loss: 0.0344
# Epoch 49/50
# 2/2 [==============================] - 22s 11s/step - loss: 0.0237 - val_loss: 0.0352
# Epoch 50/50
# 2/2 [==============================] - 21s 11s/step - loss: 0.0233 - val_loss: 0.0371

# %%
# Evaluate the model
val_loss = autoencoder.evaluate(x_val, x_val)
print('Validation loss:', val_loss)
# Out:
# 4/4 [==============================] - 2s 370ms/step - loss: 0.0372
# Validation loss: 0.037209950387477875

# %% [markdown]
# ### **4. Prediction**

# %%
# Predict ratings
predicted_ratings = autoencoder.predict(ratings_matrix) * 5.0
# Out:
# 20/20 [==============================] - 8s 376ms/step

# %%
# Recommend movies
def generate_recommendations(user_id, predicted_ratings, ratings_matrix):
    user_ratings = ratings_matrix[user_id-1]
    unseen_movies_idx = user_ratings == 0
    predicted_ratings_for_user = predicted_ratings[user_id-1]
    recommended_movies = predicted_ratings_for_user[unseen_movies_idx]
    top_recommended_movie_ids = recommended_movies.argsort()[::-1][:10]
    return top_recommended_movie_ids

user_id = 1
recommendations = generate_recommendations(user_id, predicted_ratings, ratings_matrix)
print('Recommended movie IDs for user {}: {}'.format(user_id, recommendations))
# Out:
# Recommended movie IDs for user 1: [8711 3269 5335 5244 6195 2442 5164 7371 5802 9368]
